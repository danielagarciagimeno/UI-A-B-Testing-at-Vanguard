# %% [markdown]
# 1. Client Profiles (df_final_demo): Demographics like age, gender, and account details of our clients.
# 2. Digital Footprints (df_final_web_data): A detailed trace of client interactions online, divided into two parts: pt_1 and pt_2. It’s recommended to merge these two files prior to a comprehensive data analysis.
# 3. Experiment Roster (df_final_experiment_clients): A list revealing which clients were part of the grand experiment.

# %%
import pandas as pd
df_final_web_data_pt_1 = pd.read_csv('/Users/danielebelmiro/Downloads/df_final_web_data_pt_1.txt', sep=',')

# %%
df_final_web_data_pt_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
import pandas as pd
df_final_web_data_pt_2 = pd.read_csv('/Users/danielebelmiro/Downloads/df_final_web_data_pt_2.txt', sep=',')

# %%
df_final_web_data_pt_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
df_final_web_data = pd.concat([df_final_web_data_pt_1, df_final_web_data_pt_2], axis=0, ignore_index=True)

print(df_final_web_data.head())
print(df_final_web_data.info())
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755405 entries, 0 to 755404
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
# ...

# %%
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_final_web_data_cleaned = df_final_web_data.dropna()
df_final_web_data_cleaned
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_final_web_data_cleaned = df_final_web_data_cleaned.drop_duplicates()

# %%
df_final_web_data_cleaned
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
import pandas as pd
df_final_experiment_clients = pd.read_csv('/Users/danielebelmiro/Downloads/df_final_experiment_clients.txt', sep=',')

# %%
df_final_experiment_clients
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_final_experiment_clients_cleaned = df_final_experiment_clients.dropna()
df_final_experiment_clients_cleaned
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_final_experiment_clients_cleaned.drop_duplicates(keep='first', inplace=True)
df_final_experiment_clients_cleaned
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_final_demo = pd.read_csv('/Users/danielebelmiro/Downloads/df_final_demo.txt', sep=',')

# %%
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_final_demo_cleaned = df_final_demo.dropna()
df_final_demo_cleaned
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_final_demo_cleaned.drop_duplicates(subset=None, keep='first', inplace=False)
df_final_demo_cleaned
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
# Verificar duplicatas em uma coluna específica
duplicated_ids = df_final_demo_cleaned[df_final_demo_cleaned.duplicated(subset='client_id')]

# Exibir duplicatas
print(duplicated_ids)

# Contar o número de duplicatas
print(f"Número de duplicatas por client_id: {duplicated_ids.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [client_id, clnt_tenure_yr, clnt_tenure_mnth, clnt_age, gendr, num_accts, bal, calls_6_mnth, logons_6_mnth]
# Index: []
# Número de duplicatas por client_id: 0

# %%
df_final_web_data_cleaned = df_final_web_data_cleaned.drop_duplicates(subset='client_id')
df_final_experiment_clients_cleaned = df_final_experiment_clients_cleaned.drop_duplicates(subset='client_id')

# Fazer o merge novamente
df_merged = pd.merge(df_final_web_data_cleaned, df_final_experiment_clients_cleaned, on='client_id', how='right')

# %%
df_merged
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 2        4033851  762728880_76361333336  949661017_22392791362_127391
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 4        9294070  489274391_63794562906  116640698_27328181095_188045
# ...          ...                    ...                           ...
# 50495     393005  238199953_33257685972  579367767_60788307935_908431
# 50496    2908510  814969699_90652851448   562606085_36368381773_92090
# 50497    7230446  301456995_82370441715  869576778_94474334805_445679
# 50498    5230357  832474317_11880812098   28245330_61880751416_631586
# 50499    6334360  629124187_65258232847  586047816_14599436811_389185
#
#       process_step            date_time Variation
# 0           step_3  2017-04-17 15:27:07      Test
# ...

# %%
df_merged_final = pd.merge(df_merged, df_final_demo_cleaned, on='client_id', how='inner')

df_merged_final
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 2        4033851  762728880_76361333336  949661017_22392791362_127391
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 4        9294070  489274391_63794562906  116640698_27328181095_188045
# ...          ...                    ...                           ...
# 50482     393005  238199953_33257685972  579367767_60788307935_908431
# 50483    2908510  814969699_90652851448   562606085_36368381773_92090
# 50484    7230446  301456995_82370441715  869576778_94474334805_445679
# 50485    5230357  832474317_11880812098   28245330_61880751416_631586
# 50486    6334360  629124187_65258232847  586047816_14599436811_389185
#
#       process_step            date_time Variation  clnt_tenure_yr  \
# ...

# %%
df_merged_final = df_merged_final.drop(columns=['clnt_tenure_mnth'])

# %% [markdown]
# - client_id: Every client’s unique ID.
# - variation: Indicates if a client was part of the experiment.
# - visitor_id: A unique ID for each client-device combination.
# - visit_id: A unique ID for each web visit/session.
# - process_step: Marks each step in the digital process.
# - date_time: Timestamp of each web activity.
# - clnt_tenure_yr: Represents how long the client has been with Vanguard, measured in years.
# - clnt_tenure_mnth: Further breaks down the client’s tenure with Vanguard in months.
# - clnt_age: Indicates the age of the client.
# - gendr: Specifies the client’s gender.
# - num_accts: Denotes the number of accounts the client holds with Vanguard.
# - bal: Gives the total balance spread across all accounts for a particular client.
# - calls_6_mnth: Records the number of times the client reached out over a call in the past six months.
# - logons_6_mnth: Reflects the frequency with which the client logged onto Vanguard’s platform over the last six months.

# %%
df_merged_final
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 2        4033851  762728880_76361333336  949661017_22392791362_127391
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 4        9294070  489274391_63794562906  116640698_27328181095_188045
# ...          ...                    ...                           ...
# 50482     393005  238199953_33257685972  579367767_60788307935_908431
# 50483    2908510  814969699_90652851448   562606085_36368381773_92090
# 50484    7230446  301456995_82370441715  869576778_94474334805_445679
# 50485    5230357  832474317_11880812098   28245330_61880751416_631586
# 50486    6334360  629124187_65258232847  586047816_14599436811_389185
#
#       process_step            date_time Variation  clnt_tenure_yr  clnt_age  \
# ...

# %%
df_merged_final_test = df_merged_final[df_merged_final['Variation'] == 'Test']
df_merged_final_control = df_merged_final[df_merged_final['Variation'] == 'Control']

print(df_merged_final_test)
print(df_merged_final_control)
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        8320017   39393514_33118319366  960651974_70596002104_312201
# 3        1982004  618934751_10082078917   132494692_73738638511_70823
# 5        9466803    97277031_5793723360   812185460_4263902139_352107
# 6        3170143  837774974_91015515080  758001412_25057963943_219559
# ...          ...                    ...                           ...
# 50477    5969816  470587199_31947711941  312260787_57270254471_839042
# 50479    8692087  701415208_39077478279  213110505_37474845174_503733
# 50484    7230446  301456995_82370441715  869576778_94474334805_445679
# 50485    5230357  832474317_11880812098   28245330_61880751416_631586
# 50486    6334360  629124187_65258232847  586047816_14599436811_389185
#
#       process_step            date_time Variation  clnt_tenure_yr  clnt_age  \
# ...

# %%
df_final_web_data = df_final_web_data.dropna()

# %%
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_final_web_data = df_final_web_data.drop_duplicates()

# %%
#df huella digital
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_final_web_data = df_final_web_data.sort_values(by=['client_id', 'visit_id', 'date_time'])
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 285515        169  201385055_71273495308  749567106_99161211863_557568
# 285514        169  201385055_71273495308  749567106_99161211863_557568
# 285513        169  201385055_71273495308  749567106_99161211863_557568
# 285512        169  201385055_71273495308  749567106_99161211863_557568
# 285511        169  201385055_71273495308  749567106_99161211863_557568
# ...           ...                    ...                           ...
# 648533    9999875   738878760_1556639849    931268933_219402947_599432
# 648532    9999875   738878760_1556639849    931268933_219402947_599432
# 648531    9999875   738878760_1556639849    931268933_219402947_599432
# 648530    9999875   738878760_1556639849    931268933_219402947_599432
# 648529    9999875   738878760_1556639849    931268933_219402947_599432
#
#        process_step           date_time
# 285515        start 2017-04-12 20:19:36
# ...

# %%
# df con datos de clientes grupo de test
df_merged_final_test = df_merged_final_test.drop(columns=['visitor_id', 'visit_id', 'process_step', 'date_time', 'Variation'])

df_merged_final_test
# Out:
#        client_id  clnt_tenure_yr  clnt_age gendr  num_accts        bal  \
# 0        9988021             5.0      79.0     U        2.0  189023.86
# 1        8320017            22.0      34.5     M        2.0   36001.90
# 3        1982004             6.0      44.5     U        2.0   30231.76
# 5        9466803            11.0      27.0     F        2.0   46131.19
# 6        3170143            21.0      53.5     F        2.0  192109.59
# ...          ...             ...       ...   ...        ...        ...
# 50477    5969816            19.0      26.5     F        2.0   35887.12
# 50479    8692087            14.0      60.5     F        3.0   85826.90
# 50484    7230446             6.0      62.0     M        2.0   58778.11
# 50485    5230357            23.0      30.5     M        2.0   61349.70
# 50486    6334360             4.0      66.5     U        2.0   93103.47
#
#        calls_6_mnth  logons_6_mnth
# 0               1.0            4.0
# 1               5.0            8.0
# ...

# %%
# df con datos de clientes grupo de control
df_merged_final_control = df_merged_final_control.drop(columns=['visitor_id', 'visit_id', 'process_step', 'date_time', 'Variation'])
df_merged_final_control
# Out:
#        client_id  clnt_tenure_yr  clnt_age gendr  num_accts        bal  \
# 2        4033851            12.0      63.5     M        2.0  142642.26
# 4        9294070             5.0      29.0     U        2.0   34254.54
# 7        6651403            13.0      56.5     M        2.0  324712.88
# 9        2105948             6.0      61.5     U        2.0   39795.28
# 12       9814849            12.0      32.5     F        2.0   33807.15
# ...          ...             ...       ...   ...        ...        ...
# 50478    4364429             7.0      31.5     M        2.0  106927.60
# 50480    8730282            27.0      50.0     F        3.0  464879.31
# 50481    5305116            18.0      63.5     F        3.0   89726.65
# 50482     393005            15.0      52.5     M        2.0   60344.67
# 50483    2908510            21.0      34.0     M        3.0  141808.05
#
#        calls_6_mnth  logons_6_mnth
# 2               5.0            8.0
# 4               0.0            3.0
# ...

# %% [markdown]
# ## completion rate

# %%
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 285515        169  201385055_71273495308  749567106_99161211863_557568
# 285514        169  201385055_71273495308  749567106_99161211863_557568
# 285513        169  201385055_71273495308  749567106_99161211863_557568
# 285512        169  201385055_71273495308  749567106_99161211863_557568
# 285511        169  201385055_71273495308  749567106_99161211863_557568
# ...           ...                    ...                           ...
# 648533    9999875   738878760_1556639849    931268933_219402947_599432
# 648532    9999875   738878760_1556639849    931268933_219402947_599432
# 648531    9999875   738878760_1556639849    931268933_219402947_599432
# 648530    9999875   738878760_1556639849    931268933_219402947_599432
# 648529    9999875   738878760_1556639849    931268933_219402947_599432
#
#        process_step           date_time
# 285515        start 2017-04-12 20:19:36
# ...

# %%
df_final_web_data['date_time'] = pd.to_datetime(df_final_web_data['date_time'])

# %%
print(df_final_web_data['date_time'].dtypes)
# Out:
# datetime64[ns]

# %%
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 285515        169  201385055_71273495308  749567106_99161211863_557568
# 285514        169  201385055_71273495308  749567106_99161211863_557568
# 285513        169  201385055_71273495308  749567106_99161211863_557568
# 285512        169  201385055_71273495308  749567106_99161211863_557568
# 285511        169  201385055_71273495308  749567106_99161211863_557568
# ...           ...                    ...                           ...
# 648533    9999875   738878760_1556639849    931268933_219402947_599432
# 648532    9999875   738878760_1556639849    931268933_219402947_599432
# 648531    9999875   738878760_1556639849    931268933_219402947_599432
# 648530    9999875   738878760_1556639849    931268933_219402947_599432
# 648529    9999875   738878760_1556639849    931268933_219402947_599432
#
#        process_step           date_time
# 285515        start 2017-04-12 20:19:36
# ...

# %%
df_final_web_data_2 = df_final_web_data.merge(df_final_experiment_clients_cleaned, on='client_id', how='inner')
df_final_web_data_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             555  402506806_56087378777  637149525_38041617439_716659
# 1             555  402506806_56087378777  637149525_38041617439_716659
# 2             555  402506806_56087378777  637149525_38041617439_716659
# 3             555  402506806_56087378777  637149525_38041617439_716659
# 4             555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 317230    9999729  834634258_21862004160  870243567_56915814033_814203
# 317231    9999729  604429154_69247391147   99583652_41711450505_426179
# 317232    9999729  604429154_69247391147   99583652_41711450505_426179
# 317233    9999832  145538019_54444341400  472154369_16714624241_585315
# 317234    9999832  145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time Variation
# 0             start 2017-04-15 12:57:56      Test
# ...

# %%
df_final_web_data_2.head(20)
# Out:
#     client_id             visitor_id                      visit_id  \
# 0         555  402506806_56087378777  637149525_38041617439_716659
# 1         555  402506806_56087378777  637149525_38041617439_716659
# 2         555  402506806_56087378777  637149525_38041617439_716659
# 3         555  402506806_56087378777  637149525_38041617439_716659
# 4         555  402506806_56087378777  637149525_38041617439_716659
# 5         647   66758770_53988066587   40369564_40101682850_311847
# 6         647   66758770_53988066587   40369564_40101682850_311847
# 7         647   66758770_53988066587   40369564_40101682850_311847
# 8         647   66758770_53988066587   40369564_40101682850_311847
# 9         647   66758770_53988066587   40369564_40101682850_311847
# 10        934  810392784_45004760546    7076463_57954418406_971348
# 11        934  810392784_45004760546    7076463_57954418406_971348
# 12        934  810392784_45004760546    7076463_57954418406_971348
# ...

# %%
df_control = df_final_web_data_2[df_final_web_data_2['Variation'] == 'Control']
df_test = df_final_web_data_2[df_final_web_data_2['Variation'] == 'Test']

# %%
df_control = df_control.sort_values(by=['client_id', 'visit_id', 'date_time'])
df_control
# Out:
#         client_id             visitor_id                      visit_id  \
# 14           1028   42237450_62128060588  557292053_87239438319_391157
# 15           1028   42237450_62128060588  557292053_87239438319_391157
# 16           1028   42237450_62128060588  557292053_87239438319_391157
# 17           1028   42237450_62128060588  557292053_87239438319_391157
# 18           1028   42237450_62128060588  557292053_87239438319_391157
# ...           ...                    ...                           ...
# 317187    9998346  292425655_16607136645  189177304_69869411700_783154
# 317188    9998346  292425655_16607136645  189177304_69869411700_783154
# 317189    9998346  292425655_16607136645  189177304_69869411700_783154
# 317190    9998346  292425655_16607136645  189177304_69869411700_783154
# 317201    9998921  960034051_85687824805    378424178_59565976155_8051
#
#        process_step           date_time Variation
# 14            start 2017-04-08 18:51:28   Control
# ...

# %%
df_test = df_test.sort_values(by=['client_id', 'visit_id', 'date_time'])
df_test
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             555  402506806_56087378777  637149525_38041617439_716659
# 1             555  402506806_56087378777  637149525_38041617439_716659
# 2             555  402506806_56087378777  637149525_38041617439_716659
# 3             555  402506806_56087378777  637149525_38041617439_716659
# 4             555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 317230    9999729  834634258_21862004160  870243567_56915814033_814203
# 317231    9999729  604429154_69247391147   99583652_41711450505_426179
# 317232    9999729  604429154_69247391147   99583652_41711450505_426179
# 317233    9999832  145538019_54444341400  472154369_16714624241_585315
# 317234    9999832  145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time Variation
# 0             start 2017-04-15 12:57:56      Test
# ...

# %%
# Completion Rate grupo test

completion_counts_test = df_test[df_test['process_step'] == 'confirm']['visit_id'].nunique()

total_visits_test = df_test[df_test['process_step'] == 'start']['visit_id'].nunique()

completion_rate_test = completion_counts_test / total_visits_test

print(completion_rate_test)
# Out:
# 0.655397050396598

# %%
# Completion Rate grupo control

completion_counts_control = df_control[df_control['process_step'] == 'confirm']['visit_id'].nunique()

total_visits_control = df_control[df_control['process_step'] == 'start']['visit_id'].nunique()

completion_rate_control = completion_counts_control / total_visits_control

print(completion_rate_control)
# Out:
# 0.5191200258815917

# %%
import matplotlib.pyplot as plt

groups = ['Control', 'Test']
completion_rates = [completion_rate_control, completion_rate_test]

plt.bar(groups, completion_rates, color=['blue', 'green'])
plt.title('Comparison of Completion Rates')
plt.ylabel('Completion Rate')
plt.ylim(0, 1)  
plt.text(0, completion_rate_control + 0.02, f"{completion_rate_control:.2%}", ha='center')
plt.text(1, completion_rate_test + 0.02, f"{completion_rate_test:.2%}", ha='center')
plt.show()

# %% [markdown]
# ## Time Spent on Each Step

# %%
# Crear una nueva columna con la marca de tiempo de la siguiente etapa para cada visita
df_control.loc[:, 'next_date_time'] = df_control.groupby('visit_id')['date_time'].shift(-1)

# Calcular el tiempo dedicado en cada etapa (en segundos)
df_control.loc[:, 'time_spent'] = (df_control['next_date_time'] - df_control['date_time']).dt.total_seconds()

# Calcular el promedio de tiempo dedicado por etapa
time_spent_avg_control = df_control.groupby('process_step')['time_spent'].mean()

# Mostrar los resultados
print("Tiempo promedio dedicado por etapa en el grupo de control:")
print(time_spent_avg_control)
# Out:
# Tiempo promedio dedicado por etapa en el grupo de control:
# process_step
# confirm    163.472533
# start       66.618421
# step_1      50.471740
# step_2      91.878753
# step_3     136.924564
# Name: time_spent, dtype: float64

# %%
# Crear una nueva columna con la marca de tiempo de la siguiente etapa para cada visita
df_test.loc[:, 'next_date_time'] = df_test.groupby('visit_id')['date_time'].shift(-1)

# Calcular el tiempo dedicado en cada etapa (en segundos)
df_test.loc[:, 'time_spent'] = (df_test['next_date_time'] - df_test['date_time']).dt.total_seconds()

# Calcular el promedio de tiempo dedicado por etapa
time_spent_avg_test = df_test.groupby('process_step')['time_spent'].mean()

# Mostrar los resultados
print("Tiempo promedio dedicado por etapa en el grupo de test:")
print(time_spent_avg_test)
# Out:
# Tiempo promedio dedicado por etapa en el grupo de test:
# process_step
# confirm    235.446532
# start       61.471494
# step_1      60.646964
# step_2      88.664041
# step_3     129.648307
# Name: time_spent, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Ejemplo de datos calculados anteriormente para control y prueba (ya hechos)
# Organiza los datos en un DataFrame para facilitar la creación del gráfico

data = {
    'process_step': ['confirm', 'start', 'step_1', 'step_2', 'step_3'],
    'control': [163.472533, 66.618421, 50.471740, 91.878753, 136.924564],
    'test': [235.446532, 61.471494, 60.646964, 88.664041, 129.648307]
}

df_comparison = pd.DataFrame(data)

# Convertir los datos a formato largo para facilitar la visualización con seaborn
df_comparison_melted = df_comparison.melt(id_vars='process_step', value_vars=['control', 'test'],
                                           var_name='group', value_name='average_time')

# Crear el gráfico
plt.figure(figsize=(10, 6))

sns.barplot(x='process_step', y='average_time', hue='group', data=df_comparison_melted)

# Personalizar el gráfico
plt.title('Comparación del tiempo promedio dedicado por etapa (Grupo Control vs Grupo Test)', fontsize=14)
plt.xlabel('Etapa del Proceso', fontsize=12)
plt.ylabel('Tiempo Promedio (segundos)', fontsize=12)
plt.legend(title='Grupo', loc='upper right')

# Agregar los valores numéricos en las barras
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       xytext=(0, 9), textcoords='offset points', ha='center', va='center')

# Mostrar el gráficÇo
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Error Rate

# %% [markdown]
# Passos para calcular a taxa de erros:
# 1. Identificar quando um usuário volta para uma etapa anterior.
# 2. Contar o número de "erros" por client_id ou visit_id.
# 3. Calcular a taxa de erro: A taxa de erro pode ser calculada como a razão entre o número de erros e o número total de visitas ou clientes.

# %%
# Ordenar los dataframes por client_id, visit_id y date_time
df_control = df_control.sort_values(by=['client_id', 'visit_id', 'date_time'])
df_test = df_test.sort_values(by=['client_id', 'visit_id', 'date_time'])

# Crear una nueva columna con la siguiente etapa para cada visita
df_control['next_process_step'] = df_control.groupby('visit_id')['process_step'].shift(-1)
df_test['next_process_step'] = df_test.groupby('visit_id')['process_step'].shift(-1)

# Definir el orden de las etapas del proceso
process_steps_order = ['start', 'step_1', 'step_2', 'step_3', 'confirm']

# Identificar retrocesos (si la siguiente etapa es anterior en el proceso)
df_control['step_back'] = df_control.apply(lambda row: process_steps_order.index(row['process_step']) > process_steps_order.index(row['next_process_step']) if pd.notnull(row['next_process_step']) else False, axis=1)
df_test['step_back'] = df_test.apply(lambda row: process_steps_order.index(row['process_step']) > process_steps_order.index(row['next_process_step']) if pd.notnull(row['next_process_step']) else False, axis=1)

# %%
# Contabilizar los errores para el grupo de control
users_with_errors_control = df_control[df_control['step_back'] == True]['client_id'].unique()
num_users_with_errors_control = len(users_with_errors_control)
total_users_control = df_control['client_id'].nunique()
error_rate_control = num_users_with_errors_control / total_users_control

# Contabilizar los errores para el grupo de prueba
users_with_errors_test = df_test[df_test['step_back'] == True]['client_id'].unique()
num_users_with_errors_test = len(users_with_errors_test)
total_users_test = df_test['client_id'].nunique()
error_rate_test = num_users_with_errors_test / total_users_test

# Mostrar las tasas de error para ambos grupos
print(f'Tasa de error del grupo de control: {error_rate_control:.2%}')
print(f'Tasa de error del grupo de prueba: {error_rate_test:.2%}')
# Out:
# Tasa de error del grupo de control: 26.26%
# Tasa de error del grupo de prueba: 33.57%
